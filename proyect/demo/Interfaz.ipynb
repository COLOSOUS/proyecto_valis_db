# %% [markdown]
# Demo de interfaz con tinker

# %%
import tkinter as tk
from PIL import ImageTk, Image
from tkinter import ttk
import os



class Application(tk.Frame):
    
    def __init__(self, master=None):
        super().__init__(master)
        self.master = master
        self.configure(width=330, height=400)
        self.place(relwidth=1, relheight=1)
        
        self.pack()
        self.create_widgets()
        

    def create_widgets(self):
        self.pack()
        self.text = tk.Text(self)        
        self.msg = tk.Label(self.master, text="Ingresa la ruta del archivo aquí")
        self.msg.place(x=80, y=10)
        self.pack()
        
        self.image=Image.open("f_low.gif")
        self.image = self.image.resize((50, 50), Image.ANTIALIAS)
        self.img = ImageTk.PhotoImage(self.image,master=self.master)
        
        self.panel = tk.Label(self, image = self.img)
        
        self.panel.pack(side = "bottom", fill = "both", expand = "yes")
        self.panel.place(x=130, y=70)
        #self.text.insert(tk.INSERT, "Ingresa la ruta de archivo aqui")
        #self.text.place(x=0, y=0)
        self.pack()
        self.entry_var = tk.StringVar()
        self.input=tk.Entry(self, textvariable=self.entry_var)
        self.input.place(x=100, y=130)
        #self.input["text"] = "Ingresa la ruta de archivo"
        self.pack()
        self.hi_there = tk.Button(self)
        self.hi_there["text"] = "OK"
        self.hi_there["command"] = self.get
        self.hi_there.pack(side="top")
        self.hi_there.place(x=150, y=150)
        self.checkbox = ttk.Checkbutton(self, text="Opción")
        self.checkbox.place(x=40, y=70)
        
        
        self.quit = tk.Button(self, text="QUIT", fg="red",
                              command=self.master.destroy)
        self.quit.pack(side="bottom")
        self.quit.place(x=145, y=200)
        
        

    def get(self):
        print(self.input.get())
        
        
    def connection(self):
        return
        
        
        

root = tk.Tk()
#root.config(width=1000, height=1000)
app = Application(master=root)
app.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d40a19fa0e00> in <module>
#      69 root = tk.Tk()
#      70 #root.config(width=1000, height=1000)
# ---> 71 app = Application(master=root)
#      72 app.mainloop()
#
# <ipython-input-6-d40a19fa0e00> in __init__(self, master)
#      15
#      16         self.pack()
# ---> 17         self.create_widgets()
#      18
#      19
#
# <ipython-input-6-d40a19fa0e00> in create_widgets(self)
#      46         self.hi_there.pack(side="top")
#      47         self.hi_there.place(x=150, y=150)
# ---> 48         self.checkbox = ttk.Checkbutton(self, text="Opción",state=DISABLED)
#      49         self.checkbox.place(x=40, y=70)
#      50
#
# NameError: name 'DISABLED' is not defined

# %%
import tkinter as tk
from PIL import Image

root = tk.Tk()
file="gif1.gif"

info = Image.open(file)

frames = info.n_frames  # gives total number of frames that gif contains

# creating list of PhotoImage objects for each frames
im = [tk.PhotoImage(file=file,format=f"gif -index {i}") for i in range(frames)]

count = 0
anim = None
def animation(count):
    global anim
    im2 = im[count]

    gif_label.configure(image=im2)
    count += 1
    if count == frames:
        count = 0
    anim = root.after(50,lambda :animation(count))

def stop_animation():
    root.after_cancel(anim)

gif_label = tk.Label(root,image="")
gif_label.pack()

start = tk.Button(root,text="start",command=lambda :animation(count))
start.pack()

stop = tk.Button(root,text="stop",command=stop_animation)
stop.pack()

root.mainloop()

# %%
import tkinter as tk
from PIL import Image

root = tk.Tk()
file="gif1.gif"

info = Image.open(file)

frames = info.n_frames  # gives total number of frames that gif contains

# creating list of PhotoImage objects for each frames
im = [tk.PhotoImage(file=file,format=f"gif -index {i}") for i in range(frames)]

count = 0
anim = None
def animation(count):
    global anim
    im2 = im[count]

    gif_label.configure(image=im2)
    count += 1
    if count == frames:
        count = 0
    anim = root.after(50,lambda :animation(count))

def stop_animation():
    root.after_cancel(anim)
#animation(count)
gif_label = tk.Label(root,image="")
gif_label.pack()

start = tk.Button(root,text="start",command=lambda :animation(count))
start.pack()

stop = tk.Button(root,text="stop",command=stop_animation)
stop.pack()

root.mainloop()

# %%
import tkinter as tk
from PIL import Image

root = tk.Tk()
file="gif1.gif"

info = Image.open(file)

frames = info.n_frames  # gives total number of frames that gif contains

# creating list of PhotoImage objects for each frames
im = [tk.PhotoImage(file=file,format=f"gif -index {i}") for i in range(frames)]

count = 0
anim = None


def animation(count):
    global anim
    im2 = im[count]

    gif_label.configure(image=im2)
    count += 1
    if count == frames:
        count = 0
    anim = root.after(50,lambda :animation(count))

def stop_animation():
    root.after_cancel(anim)
animation(count)


root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-19-ad9c16cd16dc> in <module>
#      28 def stop_animation():
#      29     root.after_cancel(anim)
# ---> 30 animation(count)
#      31
#      32
#
# <ipython-input-19-ad9c16cd16dc> in animation(count)
#      20     im2 = im[count]
#      21
# ---> 22     gif_label.configure(image=im2)
#      23     count += 1
#      24     if count == frames:
#
# C:\ProgramData\Anaconda3\envs\ambiente_pytorch\lib\tkinter\__init__.py in configure(self, cnf, **kw)
#    1483         the allowed keyword arguments call the method keys.
#    1484         """
# -> 1485         return self._configure('configure', cnf, kw)
#    1486     config = configure
#    1487     def cget(self, key):
#
# C:\ProgramData\Anaconda3\envs\ambiente_pytorch\lib\tkinter\__init__.py in _configure(self, cmd, cnf, kw)
#    1474         if isinstance(cnf, str):
# ...

# %%
from tkinter import messagebox
print(messagebox.askyesno(message="¿Desea continuar?", title="Título"))
# Out:
# False

# %% [markdown]
# Conexion con la base de datos aplicar query

# %%
import pyodbc 
conn = pyodbc.connect('Driver={ODBC Driver 17 for SQL Server};'
                      'Server=Inar;'
                      'Database=AdventureWorks2014;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()
cursor.execute("""SELECT  OBJECT_NAME(IDX.OBJECT_ID) AS Table_Name,
IDX.name AS Index_Name, 
IDXPS.index_type_desc AS Index_Type, 
IDXPS.avg_fragmentation_in_percent  Fragmentation_Percentage
FROM sys.dm_db_index_physical_stats(DB_ID(), NULL, NULL, NULL, NULL) IDXPS 
INNER JOIN sys.indexes IDX  ON IDX.object_id = IDXPS.object_id 
AND IDX.index_id = IDXPS.index_id 
ORDER BY Fragmentation_Percentage DESC""")
text_sql=""
for row in cursor:
    #print(row)
    print(row[3])
    text_sql=text_sql+str(row[3])+"\n"
# Out:
# 95.35283993115318
# 94.73684210526315
# 94.6917808219178
# 88.46153846153845
# 84.33734939759037
# 66.66666666666666
# 66.66666666666666
# 66.66666666666666
# 66.66666666666666
# 66.66666666666666
# 66.66666666666666
# 66.66666666666666
# 62.5
# 57.14285714285714
# 50.0
# 50.0
# 50.0
# 50.0
# 50.0
# 50.0
# 50.0
# 50.0
# 50.0
# 50.0
# 50.0
# 50.0
# 50.0
# 50.0
# 50.0
# 50.0
# 50.0
# 50.0
# 50.0
# 50.0
# 49.35064935064935
# 40.625
# 40.0
# 36.36363636363637
# 33.33333333333333
# 33.33333333333333
# 33.33333333333333
# 31.57894736842105
# 31.25
# 30.303030303030305
# 30.0
# 28.57142857142857
# 28.57142857142857
# 28.57142857142857
# 25.64102564102564
# 25.0
# 25.0
# 25.0
# 23.076923076923077
# 21.62162162162162
# 18.627450980392158
# 17.75147928994083
# 15.577889447236181
# 15.384615384615385
# 15.384615384615385
# 15.0
# 15.0
# 12.5
# 12.174845803164388
# 11.029411764705882
# 10.687022900763358
# 10.0
# 10.0
# 9.433962264150944
# 9.090909090909092
# 8.333333333333332
# ...

# %% [markdown]
# Ventana 1 Conexión base de datos

# %%
import tkinter as tk
from PIL import ImageTk, Image
import os



class Application(tk.Frame):
    
    def __init__(self, master=None):
        super().__init__(master)
        self.master = master
        self.configure(width=330, height=300)
        self.place(relwidth=1, relheight=1)
        
        self.pack()
        self.create_widgets()
        

    def create_widgets(self):
        self.pack()
        self.text = tk.Text(self)        
        self.msg = tk.Label(self.master, text="Nombre servidor")
        self.msg.place(x=20, y=10)
       
        self.entry_var = tk.StringVar()
        self.input=tk.Entry(self, textvariable=self.entry_var)
        self.input.place(x=115, y=10)
        #-----------------------------------------------------------
        
        
        self.pack()
        self.text = tk.Text(self)        
        self.msg = tk.Label(self.master, text="Nombre DB")
        self.msg.place(x=20, y=30)
        self.pack()
        self.pack()
        self.entry_var = tk.StringVar()
        self.input2=tk.Entry(self, textvariable=self.entry_var)
        self.input2.place(x=115, y=30)
        #-----------------------------------------------------------
        
        
        self.pack()
        self.text = tk.Text(self)        
        self.msg = tk.Label(self.master, text="Usuario")
        self.msg.place(x=20, y=50)
        self.pack()
        self.pack()
        self.entry_var = tk.StringVar()
        self.input3=tk.Entry(self, textvariable=self.entry_var)
        self.input3.place(x=115, y=50)
        #-----------------------------------------------------------
         #-----------------------------------------------------------
        
        
        self.pack()
        self.text = tk.Text(self)        
        self.msg = tk.Label(self.master, text="Password")
        self.msg.place(x=20, y=70)
        self.pack()
        self.pack()
        self.entry_var = tk.StringVar()
        self.input4=tk.Entry(self, textvariable=self.entry_var)
        self.input4.place(x=115, y=70)
        #-----------------------------------------------------------
        self.pack()
        self.hi_there1 = tk.Button(self)
        self.hi_there1["text"] = "Nuevo"
        self.hi_there1["command"] = self.new
        self.hi_there1.pack(side="top")
        self.hi_there1.place(x=100, y=100)
        self.pack()
        self.hi_there2 = tk.Button(self)
        self.hi_there2["text"] = "Recordar"
        self.hi_there2["command"] = self.recovery
        self.hi_there2.pack(side="top")
        self.hi_there2.place(x=170, y=100)
        
        
        
        
        
        
        
        self.hi_there3 = tk.Button(self)
        self.hi_there3["text"] = "OK"
        self.hi_there3["command"] = self.get
        self.hi_there3.pack(side="top")
        self.hi_there3.place(x=145, y=140)
        
        
        
        self.quit = tk.Button(self, text="QUIT", fg="red",
                              command=self.master.destroy)
        self.quit.pack(side="bottom")
        self.quit.place(x=140, y=180)
        
        

    def get(self):
        print(self.input.get())
        
        
    def connection(self):
        return
    def recovery(self):
        self.input.delete(0, 'end')
        self.input2.delete(0, 'end')
        self.input3.delete(0, 'end') 
        self.input4.delete(0, 'end')
        self.input.insert(0, "Inar")
        self.input2.insert(0, "AdventureWorks2014") 
        self.input3.insert(0, "admin") 
        self.input4.insert(0, "admin")
    def new(self):
        self.input.delete(0, 'end')
        self.input2.delete(0, 'end')
        self.input3.delete(0, 'end') 
        self.input4.delete(0, 'end') 
        
       
        
        

root = tk.Tk()
#root.config(width=1000, height=1000)
app = Application(master=root)
app.mainloop()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-d35512cbd696> in <module>
# ----> 1 print(text_sql.size())
#
# AttributeError: 'str' object has no attribute 'size'

# %% [markdown]
# Ventana 2 resultados

# %%
import tkinter as tk
from tkinter import ttk

root = tk.Tk()

root.resizable(False, False)
root.title("Resultados de la fragmentacion")

# apply the grid layout
root.grid_columnconfigure(0, weight=1)
root.grid_rowconfigure(0, weight=1)

# create the text widget
text = tk.Text(root, height=10)
text.grid(row=0, column=0, sticky='ew')
text.insert(tk.INSERT, text_sql)

# create a scrollbar widget and set its command to the text widget
scrollbar = ttk.Scrollbar(root, orient='vertical', command=text.yview)
scrollbar.grid(row=0, column=1, sticky='ns')

#  communicate back to the scrollbar
text['yscrollcommand'] = scrollbar.set


root.mainloop()

# %%
import tkinter as tk
class VerticalScrolledFrame(tk.Frame):
    """A pure Tkinter scrollable frame that actually works!

    * Use the 'interior' attribute to place widgets inside the scrollable frame
    * Construct and pack/place/grid normally
    * This frame only allows vertical scrolling
    """
    def __init__(self, parent, *args, **kw):
        tk.Frame.__init__(self, parent, *args, **kw)            

        # create a canvas object and a vertical scrollbar for scrolling it
        vscrollbar = tk.Scrollbar(self, orient=tk.VERTICAL)
        vscrollbar.pack(fill=tk.Y, side=tk.RIGHT, expand=tk.FALSE)
        canvas = tk.Canvas(self, bd=0, highlightthickness=0,
                        yscrollcommand=vscrollbar.set)
        canvas.pack(side=tk.LEFT, fill=tk.BOTH, expand=tk.TRUE)
        vscrollbar.config(command=canvas.yview)

        # reset the view
        canvas.xview_moveto(0)
        canvas.yview_moveto(0)

        # create a frame inside the canvas which will be scrolled with it
        self.interior = interior = tk.Frame(canvas)
        interior_id = canvas.create_window(0, 0, window=interior,
                                           anchor=tk.NW)

        # track changes to the canvas and frame width and sync them,
        # also updating the scrollbar
        def _configure_interior(event):
            # update the scrollbars to match the size of the inner frame
            size = (interior.winfo_reqwidth(), interior.winfo_reqheight())
            canvas.config(scrollregion="0 0 %s %s" % size)
            if interior.winfo_reqwidth() != canvas.winfo_width():
                # update the canvas's width to fit the inner frame
                canvas.config(width=interior.winfo_reqwidth())

        interior.bind('<Configure>', _configure_interior)

        def _configure_canvas(event):
            if interior.winfo_reqwidth() != canvas.winfo_width():
                # update the inner frame's width to fill the canvas
                canvas.itemconfigure(interior_id, width=canvas.winfo_width())
        canvas.bind('<Configure>', _configure_canvas)

        
root = tk.Tk()
root.title("Scrollable Frame Demo")
root.configure(background="gray99") 
scframe = VerticalScrolledFrame(root)
scframe.pack()
#-------------------------------------        
text = tk.Text(scframe.interior)        
msg = tk.Label(scframe.interior, text="Resultados de la fragmentacion")
#self.msg.place(x=120, y=10)
msg.pack(padx=10, pady=5, side=tk.TOP)


#----------------------------------------
# create the text widget
text2 = tk.Text(scframe.interior, height=10)
#text2.grid(row=0, column=0, sticky='ew')
text2.insert(tk.INSERT, text_sql)
#msg2 = tk.Label(scframe.interior, text=text2)
#msg2.pack(padx=10, pady=5, side=tk.TOP)

#-----------------------------------------------------
#for row in cursor:
    
   # text_sql=text_sql+str(row[3])+"\n"

# create a scrollbar widget and set its command to the text widget
scrollbar = ttk.Scrollbar(scframe.interior, orient='vertical', command=text2.yview)
scrollbar.pack(padx=10, pady=5, side=tk.TOP)
#scrollbar.grid(row=0, column=1, sticky='ns')

#  communicate back to the scrollbar
text2['yscrollcommand'] = scrollbar.set
#scrollbar.pack(padx=10, pady=5, side=tk.TOP)
#-------------------------------------------------------

hi_there3 = tk.Button(scframe.interior,height=1, width=20, relief=tk.FLAT)
hi_there3["text"] = "OK"
#hi_there3["command"] = get

hi_there3.pack(padx=10, pady=5, side=tk.TOP)


quit = tk.Button(scframe.interior, height=1, width=20, relief=tk.FLAT, 
        bg="gray99",
        font="Dosis", text="QUIT", fg="red",
                      command=root.destroy)


quit.pack(padx=10, pady=5, side=tk.TOP)

"""

lis = list('ABCDEFGHIJKLMNOPQRSTUVWXYZ')
for i, x in enumerate(lis):
    btn = tk.Button(scframe.interior, height=1, width=20, relief=tk.FLAT, 
        bg="gray99", fg="purple3",
        font="Dosis", text='Button ' + lis[i],
        command=lambda i=i,x=x: openlink(i))
    btn.pack(padx=10, pady=5, side=tk.TOP)

def openlink(i):
    print(lis[i])
"""
root.mainloop()

# %% [markdown]
# Ventanas

# %%
try:
    import tkinter as tk                # python 3
    from tkinter import font as tkfont  # python 3
except ImportError:
    import Tkinter as tk     # python 2
    import tkFont as tkfont  # python 2

class SampleApp(tk.Tk):

    def __init__(self, *args, **kwargs):
        tk.Tk.__init__(self, *args, **kwargs)

        self.title_font = tkfont.Font(family='Helvetica', size=18, weight="bold", slant="italic")

        # the container is where we'll stack a bunch of frames
        # on top of each other, then the one we want visible
        # will be raised above the others
        container = tk.Frame(self)
        container.pack(side="top", fill="both", expand=True)
        container.grid_rowconfigure(0, weight=1)
        container.grid_columnconfigure(0, weight=1)

        self.frames = {}
        for F in (StartPage, PageOne, PageTwo):
            page_name = F.__name__
            frame = F(parent=container, controller=self)
            self.frames[page_name] = frame

            # put all of the pages in the same location;
            # the one on the top of the stacking order
            # will be the one that is visible.
            frame.grid(row=0, column=0, sticky="nsew")

        self.show_frame("StartPage")

    def show_frame(self, page_name):
        '''Show a frame for the given page name'''
        frame = self.frames[page_name]
        frame.tkraise()


class StartPage(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        label = tk.Label(self, text="This is the start page", font=controller.title_font)
        label.pack(side="top", fill="x", pady=10)

        button1 = tk.Button(self, text="Go to Page One",
                            command=lambda: controller.show_frame("PageOne"))
        button2 = tk.Button(self, text="Go to Page Two",
                            command=lambda: controller.show_frame("PageTwo"))
        button1.pack()
        button2.pack()


class PageOne(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        label = tk.Label(self, text="This is page 1", font=controller.title_font)
        label.pack(side="top", fill="x", pady=10)
        button = tk.Button(self, text="Go to the start page",
                           command=lambda: controller.show_frame("StartPage"))
        button.pack()


class PageTwo(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        label = tk.Label(self, text="This is page 2", font=controller.title_font)
        label.pack(side="top", fill="x", pady=10)
        button = tk.Button(self, text="Go to the start page",
                           command=lambda: controller.show_frame("StartPage"))
        button.pack()
if __name__ == "__main__":
    app = SampleApp()
    app.mainloop()

# %%
class VerticalScrolledFrame(tk.Frame):
    """A pure Tkinter scrollable frame that actually works!

    * Use the 'interior' attribute to place widgets inside the scrollable frame
    * Construct and pack/place/grid normally
    * This frame only allows vertical scrolling
    """
    def __init__(self, parent, *args, **kw):
        tk.Frame.__init__(self, parent, *args, **kw)            

        # create a canvas object and a vertical scrollbar for scrolling it
        vscrollbar = tk.Scrollbar(self, orient=tk.VERTICAL)
        vscrollbar.pack(fill=tk.Y, side=tk.RIGHT, expand=tk.FALSE)
        canvas = tk.Canvas(self, bd=0, highlightthickness=0,
                        yscrollcommand=vscrollbar.set)
        canvas.pack(side=tk.LEFT, fill=tk.BOTH, expand=tk.TRUE)
        vscrollbar.config(command=canvas.yview)

        # reset the view
        canvas.xview_moveto(0)
        canvas.yview_moveto(0)

        # create a frame inside the canvas which will be scrolled with it
        self.interior = interior = tk.Frame(canvas)
        interior_id = canvas.create_window(0, 0, window=interior,
                                           anchor=tk.NW)

        # track changes to the canvas and frame width and sync them,
        # also updating the scrollbar
        def _configure_interior(event):
            # update the scrollbars to match the size of the inner frame
            size = (interior.winfo_reqwidth(), interior.winfo_reqheight())
            canvas.config(scrollregion="0 0 %s %s" % size)
            if interior.winfo_reqwidth() != canvas.winfo_width():
                # update the canvas's width to fit the inner frame
                canvas.config(width=interior.winfo_reqwidth())

        interior.bind('<Configure>', _configure_interior)

        def _configure_canvas(event):
            if interior.winfo_reqwidth() != canvas.winfo_width():
                # update the inner frame's width to fill the canvas
                canvas.itemconfigure(interior_id, width=canvas.winfo_width())
        canvas.bind('<Configure>', _configure_canvas)


root = tk.Tk()
root.title("Scrollable Frame Demo")
root.configure(background="gray99")

scframe = VerticalScrolledFrame(root)
scframe.pack()

lis = list('ABCDEFGHIJKLMNOPQRSTUVWXYZ')
for i, x in enumerate(lis):
    btn = tk.Button(scframe.interior, height=1, width=20, relief=tk.FLAT, 
        bg="gray99", fg="purple3",
        font="Dosis", text='Button ' + lis[i],
        command=lambda i=i,x=x: openlink(i))
    btn.pack(padx=10, pady=5, side=tk.TOP)

def openlink(i):
    print(lis[i])

root.mainloop()
